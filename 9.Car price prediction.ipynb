# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv('CarPrice_Assignment.csv')
cars
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
X = cars.drop('price', axis=1).copy()
y = cars.price

# %%
X.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  cylindernumber  \
# 0  convertible        rwd          front       88.6  ...            four
# 1  convertible        rwd          front       88.6  ...            four
# 2    hatchback        rwd          front       94.5  ...             six
# 3        sedan        fwd          front       99.8  ...            four
# 4        sedan        4wd          front       99.4  ...            five
#
# ...

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
X.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
X_num = X.select_dtypes(['int', 'float'])
X_num
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
X_cat = X.select_dtypes('object')
X_cat
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype cylindernumber fuelsystem
# ...

# %%
for i in X_num:
    plt.figure(dpi=120)
    r = np.corrcoef(X_num[i], y)[0,1]
    sns.scatterplot(x=X_num[i], y=y, label=f"r = {r:.2f}")
    plt.title(f"{i} vs car_price")
    plt.show()

# %% [markdown]
#     carid, symboling, stroke, compressionratio, peakrpm

# %%
X
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
X_cat
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype cylindernumber fuelsystem
# ...

# %%
for i in X_cat:
    if i == 'CarName':
        continue
    print(X_cat[i].value_counts() / X_cat.shape[0] * 100)
    print()
# Out:
# fueltype
# gas       90.243902
# diesel     9.756098
# Name: count, dtype: float64
#
# aspiration
# std      81.95122
# turbo    18.04878
# Name: count, dtype: float64
#
# doornumber
# four    56.097561
# two     43.902439
# Name: count, dtype: float64
#
# carbody
# sedan          46.829268
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: count, dtype: float64
#
# drivewheel
# fwd    58.536585
# rwd    37.073171
# 4wd     4.390244
# Name: count, dtype: float64
#
# enginelocation
# front    98.536585
# rear      1.463415
# Name: count, dtype: float64
#
# enginetype
# ohc      72.195122
# ohcf      7.317073
# ohcv      6.341463
# dohc      5.853659
# l         5.853659
# rotor     1.951220
# dohcv     0.487805
# Name: count, dtype: float64
#
# cylindernumber
# four      77.560976
# six       11.707317
# five       5.365854
# eight      2.439024
# two        1.951220
# three      0.487805
# twelve     0.487805
# ...

# %%
cars
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
plt.figure(dpi=130)
sns.scatterplot(data=cars, x='horsepower', y='price', hue='doornumber')
plt.show()

# %%
plt.figure(dpi=130)
sns.scatterplot(data=cars, x='horsepower', y='price', hue='carbody')
plt.show()

# %%
cars['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
cars['cylindernumber'].value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64

# %%
size = cars['cylindernumber'].map({'four': 10, 'six':20, 'five':30, 'eight': 40, 'two':50, 'three':60, 'twelve':90})
size
# Out:
# 0      10
# 1      10
# 2      20
# 3      10
# 4      30
#        ..
# 200    10
# 201    10
# 202    20
# 203    20
# 204    10
# Name: cylindernumber, Length: 205, dtype: int64

# %%
plt.figure(dpi=130)
sns.scatterplot(data=cars, x='horsepower', y='price', hue='doornumber', s=size)
plt.show()

# %%
X
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
X.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
X.drop(['car_ID', 'symboling', 'stroke', 'compressionratio', 'peakrpm', 'CarName'], axis=1, inplace=True)

# %%
X
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#      wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
X_train
# Out:
#     fueltype aspiration doornumber    carbody drivewheel enginelocation  \
# 197      gas        std       four      wagon        rwd          front
# 112   diesel      turbo       four      sedan        rwd          front
# 95       gas        std        two  hatchback        fwd          front
# 169      gas        std        two  hatchback        rwd          front
# 184   diesel        std       four      sedan        fwd          front
# ..       ...        ...        ...        ...        ...            ...
# 17       gas        std       four      sedan        rwd          front
# 98       gas        std        two    hardtop        fwd          front
# 66    diesel        std       four      sedan        rwd          front
# 126      gas        std        two    hardtop        rwd           rear
# 109      gas        std       four      wagon        rwd          front
#
#      wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# ...

# %%
X_test
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 88       gas        std       four        sedan        fwd          front
# 72       gas        std        two  convertible        rwd          front
# 114   diesel      turbo       four        wagon        rwd          front
# 158   diesel        std       four        sedan        fwd          front
# 163      gas        std        two        sedan        rwd          front
# 159   diesel        std       four    hatchback        fwd          front
# 185      gas        std       four        sedan        fwd          front
# 93       gas        std       four        wagon        fwd          front
# 91       gas        std        two        sedan        fwd          front
# 19       gas        std        two    hatchback        fwd          front
# 160      gas        std       four        sedan        fwd          front
# 82       gas      turbo        two    hatchback        fwd          front
# ...

# %%
numerical_features = X.select_dtypes(['int', 'float']).columns
numerical_features
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'horsepower', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
cat_features = X.select_dtypes('object').columns
cat_features
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'],
#       dtype='object')
